# %%
num_head = 9
emb_dim = 512
from torch.functional import F
import torch

inputs = [-torch.inf, -torch.inf, -torch.inf]
inputs = torch.tensor(inputs, device="cuda")
res = F.softmax(inputs, dim=-1)
print(res)
# Out:
# tensor([nan, nan, nan], device='cuda:0')
